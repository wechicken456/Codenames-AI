# %%
import httpx
import asyncio
import spacy
from openai import OpenAI
from dotenv import load_dotenv
import os
from nltk.stem import WordNetLemmatizer
import lemminflect
import time
import networkx as nx
from collections import defaultdict
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from nltk.corpus import wordnet as wn



load_dotenv()
#openAI_api_key = "ENTER YOUR API KEY HERE"
openAI_api_key = os.environ.get("OPENAI_API_KEY")
openAI_client = OpenAI(api_key=openAI_api_key)

# Download necessary data for WordNetLemmatizer if we haven't already
try:
    WordNetLemmatizer().lemmatize("test") # Just a test to trigger lookup error if not downloaded
except LookupError:
    nltk.download('wordnet')
    nltk.download('omw-1.4') # Open Multilingual Wordnet, often needed for full WordNet functionality

# %%
allowed_word_types = [
    "ADJ",	
    "ADV",
    "INTJ",	
    "NOUN",
    "PROPN",	
    "VERB"
]

NOUN_RELS = ["RelatedTo", "CapableOf", "IsA", "UsedFor", "AtLocation", "HasPrerequisite", "HasProperty", "ReceivesAction", "CreatedBy", "Causes", "HasA", "MadeOf"]
NOUN_REV_RELS = ["AtLocation", "IsA", "PartOf"]
VERB_RELS = ["MannerOf", "HasSubevent", "MotivatedByGoal", "IsA", "HasFirstSubevent", "HasLastSubevent"]
VERB_REV_RELS = ["CapableOf", "MannerOf", "CausesDesire", "UsedFor", "CreatedBy", "ReceivesAction", "HasFirstSubevent"]
ADJ_RELS = ["SimilarTo", "RelatedTo", "HasProperty"] 


stopwords = set([
    'ourselves', 'hers', 'between', 'yourself', 'but', 'again', 'there', 'about', 'once', 'during', 'out', 'very', 'having', 'with', 'they', 'own', 'an', 'be', 'some', 'for', 'do', 'its', 'yours', 'such', 'into', 'of', 'most', 'itself', 'other', 'off', 'is', 's', 'am', 'or', 'who', 'as', 'from', 'him', 'each', 'the', 'themselves', 'until', 'below', 'are', 'we', 'these', 'your', 'his', 'through', 'don', 'nor', 'me', 'were', 'her', 'more', 'himself', 'this', 'down', 'should', 'our', 'their', 'while', 'above', 'both', 'up', 'to', 'ours', 'had', 'she', 'all', 'no', 'when', 'at', 'any', 'before', 'them', 'same', 'and', 'been', 'have', 'in', 'will', 'on', 'does', 'yourselves', 'then', 'that', 'because', 'what', 'over', 'why', 'so', 'can', 'did', 'not', 'now', 'under', 'he', 'you', 'herself', 'has', 'just', 'where', 'too', 'only', 'myself', 'which', 'those', 'i', 'after', 'few', 'whom', 't', 'being', 'if', 'theirs', 'my', 'against', 'a', 'by', 'doing', 'it', 'how', 'further', 'was', 'here', 'than', 'get', 'put',
])

# %%
lemmatizer = WordNetLemmatizer()
def get_word_lemma(word : str, pos_hint : str = None) -> str:
    """
    Gets the lemma of a single word without sentence context using NLTK's WordNetLemmatizer.
    pos_hint can be 'n' (noun), 'v' (verb), 'a' (adjective), 'r' (adverb).
    Defaults to 'n' if no hint is given.
    """
    return lemmatizer.lemmatize(word.lower(), pos=pos_hint) if pos_hint else lemmatizer.lemmatize(word.lower())

def get_all_possible_lemmas(word: str) -> list[str]:
    res = []
    for hint in ["v", "n", "a", "r", "s"]:
        res.append(get_word_lemma(word, hint))
    return res

def get_all_inflections(word : str) -> list[str]:
    inflections = lemminflect.getAllInflections(word)
    res = []
    for _, i in inflections.items():
        res += list(i)
    return res

def get_word_classes(word : str) -> set:
    pos_set = set()
    for synset in wn.synsets(word):
        #print(f"Synset: {synset}")
        if synset.name().split('.')[0] != word:
            continue  # Only consider exact matches
        if synset.pos() == 'n':
            pos_set.add('noun')
        elif synset.pos() == 'v':
            pos_set.add('verb')
        elif synset.pos() == 's':
            pos_set.add('adj')

    if len(pos_set) == 0: pos_set.add('noun') # default to noun if unidentified 
    return pos_set

def remove_stopwords(words : str) -> str:
    word_list = words.split()
    filtered_words = [word for word in word_list if word.lower() not in stopwords]
    return " ".join(filtered_words)
    

class Codemaster:
    def __init__(self, our_words : list[str], enemy_words : list[str], civilian_words : list[str], assassin_word : str, my_team : str):
        self.our_words = our_words
        self.enemy_words = enemy_words
        self.civilian_words = civilian_words
        self.assassin_word = assassin_word
        self.my_team = my_team
        self.all_board_words = set(our_words + enemy_words + civilian_words + [assassin_word])

        self.clue_candidates = defaultdict(list)
        self.min_clue_weight_threshold = 1.4

        # Spacy
        self.nlp = spacy.load("en_core_web_trf")

        # API clients
        self.conceptnet_client = httpx.AsyncClient(http2=True)
        self.openai_client = OpenAI(api_key=openAI_api_key)

        # All forms of board words
        self.lemmas = set()
        for word in self.all_board_words:
            self.lemmas.update(word)
            self.lemmas.update(get_all_inflections(word))
            self.lemmas.update(get_all_possible_lemmas(word))

        # Create graph from ConceptNet queries
        self.graph = nx.DiGraph()


    async def fetch_conceptnet(self, url : str) -> dict:
        r = await self.conceptnet_client.get(url, follow_redirects=True)
        return r.json()
    
    def _filter(self, words: str) -> list[str]:
        """
        return the filtered list of words. Each word must NOT appear as a lemma or an inflection of any words on the board (which is given by self.lemmas).
        """
        doc = self.nlp(words)
        l = list(filter(lambda token: (token.pos_ in allowed_word_types) and (token.lemma_ not in self.lemmas) and (token.text not in self.lemmas), doc)) 
        # l is a list of tokens, convert them to string to return
        return [token.text for token in l]
    
    def _process_edge(self, edge : dict, target_word):
        """
        for a given target word, and a given edge it has on ConceptNet, process the node this edge points to:
            + First, the node has to be in English.
            + Second, the node may be multi-word, so we need to process each individual word in it. 
            Keep the open class words (adjective, nouns, verbs, etc) as specified in the universal POS tags: https://universaldependencies.org/u/pos/
            + Then, we need to make sure that each word follows the rules of the game (no subword embedding, etc).
        The `self.filter` function performs the last 2 filters.
        """

        # find whether our target word is at the start node or end node of this edge
        start_node = edge["start"]
        end_node = edge["end"]

        start_node_label = remove_stopwords(start_node["label"])
        end_node_label = remove_stopwords(end_node["label"])
        
        if target_word in start_node_label:
            if end_node["language"] != "en": return []
            label_words = self._filter(end_node_label)
        else:
            if start_node["language"] != "en": return []
            label_words = self._filter(start_node_label)
        return label_words

    async def _fetch_relations(self, target_word: str, rel_list: list, is_rev: bool = False) -> set:
        """Generic function to fetch and process edges for a list of relations. Create multiple parallel tasks to process these relations."""
        clues = set()
        tasks = []
        for rel in rel_list:
            node_param = "end" if is_rev else "start"
            url = f"http://api.conceptnet.io/query?{node_param}=/c/en/{target_word}&rel=/r/{rel}&limit=10"
            tasks.append(self.conceptnet_client.get(url, follow_redirects=True))

        responses = await asyncio.gather(*tasks, return_exceptions=True)
        
        for i, res in enumerate(responses):
            if isinstance(res, Exception):
                # print(f"Warning: Request for {target_word} with relation {rel_list[i]} failed: {res}")
                continue
            
            try:
                api_res = res.json()
                relation_name = rel_list[i]
                for edge in api_res.get("edges", []):
                    processed_clues = self._process_edge(edge, target_word)
                    for clue in processed_clues:
                        clues.add((clue, relation_name, is_rev))
            except (ValueError, KeyError) as e:
                # print(f"Warning: Could not parse JSON for {target_word} with relation {rel_list[i]}: {e}")
                continue
        return clues

    
    async def _fetch_clues_for_word(self, word: str, specific_rels: list = None) -> dict:
        """
        Fetches all potential clues for a single word. Depending on its POS (Part Of Speech), use the relation list accordingly.
        If specific_rels is provided, use those relations instead.
        """
        clues_by_pos = {'noun': set(), 'verb': set(), 'adj': set()}
        word_classes = get_word_classes(word)

        for pos in word_classes:
            rels, rev_rels = [], []
            if specific_rels:
                rels = specific_rels
                rev_rels = specific_rels
            elif pos == 'noun':
                rels, rev_rels = NOUN_RELS, NOUN_REV_RELS
            elif pos == 'verb':
                rels, rev_rels = VERB_RELS, VERB_REV_RELS
            elif pos == 'adj':
                rels, rev_rels = ADJ_RELS, []

            forward_clues, reverse_clues = await asyncio.gather(
                self._fetch_relations(word, rels, is_rev=False),
                self._fetch_relations(word, rev_rels, is_rev=True)
            )
            clues_by_pos[pos].update(forward_clues)
            clues_by_pos[pos].update(reverse_clues)
        return clues_by_pos

    async def build_clue_graph(self):
        """Builds the clue graph by querying ConceptNet up to 2 levels deep."""     

        total_start = time.time()
        
        # Add all board words first
        for word in self.our_words: self.graph.add_node(word, type='our_word')
        for word in self.enemy_words: self.graph.add_node(word, type='enemy_word')
        for word in self.civilian_words: self.graph.add_node(word, type='civilian_word')
        self.graph.add_node(self.assassin_word, type='assassin_word')

        # Use a temporary dict to store max weights before sorting
        temp_candidates = defaultdict(dict)

        # Step 1: populate graph with depth-1 clues
        print("\n--- Building Clue Graph (Depth 1) ---")
        d1_tasks = []
        for word in self.our_words:
            d1_tasks.append(self._fetch_clues_for_word(word))
        
        d1_results = await asyncio.gather(*d1_tasks)
        
        d1_clues_for_stage2 = []
        for i, clues_by_pos in enumerate(d1_results):
            source_word = self.our_words[i]
            # Check if the word is a landmark
            doc = self.nlp(source_word)
            is_landmark = doc.ents and doc.ents[0].label_ in ["GPE", "LOC"]
            
            for pos, clue_tuples in clues_by_pos.items():
                for clue, relation, is_rev in clue_tuples:
                    if clue in self.all_board_words: continue

                    weight = self.relation_weights.get(pos, {}).get(relation, 1.3)
                    if is_rev: weight *= self.reverse_relation_penalty

                    
                    if is_landmark and relation == 'AtLocation':
                        weight *= self.landmark_location_bonus
                    
                    if weight > self.min_clue_weight_threshold:
                        # Add to graph, replacing edge if new one is stronger
                        if not self.graph.has_edge(source_word, clue):
                            self.graph.add_edge(source_word, clue, weight=weight)
                        else:
                            if weight > self.graph[source_word][clue]['weight']:
                                self.graph.remove_edge(source_word, clue)
                                self.graph.add_edge(source_word, clue, weight=weight)

                        current_max = temp_candidates[source_word].get(clue, -1)
                        temp_candidates[source_word][clue] = max(current_max, weight)
                        d1_clues_for_stage2.append((source_word, clue, pos, relation))

        print(f"Graph after Depth 1: {self.graph.number_of_nodes()} nodes, {self.graph.number_of_edges()} edges.")
        print(f"Time taken: {time.time() - total_start}")

        print("\n--- Building Clue Graph (Depth 2) ---")
        start_2 = time.time()
        d2_tasks = []
        for source_word, d1_clue, pos, rel in d1_clues_for_stage2:
            d2_tasks.append(self._fetch_clues_for_word(d1_clue, specific_rels=[rel]))
        
        d2_results = await asyncio.gather(*d2_tasks)

        for i, clues_by_pos in enumerate(d2_results):
            source_word, d1_clue, pos, _ = d1_clues_for_stage2[i]
            d1_weight = self.graph[source_word][d1_clue]['weight']

            for _, clue_tuples in clues_by_pos.items():
                for d2_clue, d2_relation, is_rev in clue_tuples:
                    if d2_clue in self.all_board_words: continue

                    d2_weight = self.relation_weights.get(pos, {}).get(d2_relation, 1.3)
                    if is_rev: d2_weight *= self.reverse_relation_penalty
                    
                    total_path_weight = (d1_weight + (d2_weight * 0.8)) / 2 # Apply decay for depth 2

                    if total_path_weight > self.min_clue_weight_threshold:
                        # Add to graph, replacing edge if new one is stronger
                        if not self.graph.has_edge(d1_clue, d2_clue):
                            self.graph.add_edge(d1_clue, d2_clue, weight=d2_weight)
                        else:
                            if d2_weight > self.graph[d1_clue][d2_clue]['weight']:
                                self.graph.remove_edge(d1_clue, d2_clue)
                                self.graph.add_edge(d1_clue, d2_clue, weight=d2_weight)
                        
                        current_max = temp_candidates[source_word].get(d2_clue, -1)
                        temp_candidates[source_word][d2_clue] = max(current_max, total_path_weight)
        print(f"Finished stage 2.\nTime taken: {time.time() - start_2}")

        # --- Finalize: Sort and store the candidate lists ---
        for word, candidates in temp_candidates.items():
            sorted_list = sorted(candidates.items(), key=lambda item: item[1], reverse=True)
            self.clue_candidates[word] = [(weight, clue) for clue, weight in sorted_list]
        
        print("\n--- Finished building graph ---")
        print(f"Total time taken: {time.time() - total_start}")

        
    def find_candidate_clues(self, target_words: list[str]) -> set:
        """
        Finds candidate clues by intersecting the pre-computed clue lists.
        """
        if not target_words:
            return set()

        # Get the list of set of candidate clues for each target word
        try:
            candidate_sets = [set(clue for _, clue in self.clue_candidates[word]) for word in target_words]
        except KeyError:
            return set() # A target word might have no valid clues
        
        if not candidate_sets:
            return set()

        # Get intersection of all the sets
        intersection = candidate_sets[0].intersection(*candidate_sets[1:])
        return intersection

    def calculate_graph_score(self, clue: str, target_words: list[str]) -> float:
        """
        Calculates a score based on the pre-computed weights in the candidate lists.
        """
        total_weight = 0.0
        
        # Create a quick lookup map for each target's clues
        candidate_maps = {word: {c: w for w, c in self.clue_candidates.get(word,)} for word in target_words}

        for word in target_words:
            # Add the pre-computed max path weight for this clue
            total_weight += candidate_maps[word].get(clue, 0)

        if total_weight == 0:
            return 0.0
        
        # Reward clues that connect more words
        return total_weight * (len(target_words) ** 2)

# %%
start = time.time()
blue_words = ["dwarf", "foot", "moon", "star", "ghost", "beijing", "fighter", "roulette", "alps"]
#red_words = ["club", "superhero", "mount", "bomb", "knife", "belt", "robot", "rock", "bar", "lab"]
red_words = ["drive"]
civilian_words = ["dead"]
assassin_word = "agent"
master = Codemaster(blue_words, red_words, civilian_words, assassin_word, "red")
candidates = await master.build_clue_graph()

    
print(f"Time taken: {time.time() - start}")
# Out:
# --- Building Clue Graph (Depth 1) ---
# Graph after Depth 1: 285 nodes, 292 edges.
# Time taken: 9.568947792053223
#
# --- Building Clue Graph (Depth 2) ---
# Finished stage 2.
# Time taken: 111.04610061645508
#
# --- Finished building graph ---
# Total time taken: 120.61553025245667
# Time taken: 122.03094983100891

# %%
for word, clues in master.clue_candidates.items():
    print(f"------ {word} ---------")
    for clue in clues:
        print(f"Clue: {clue[1]}, Weight: {clue[0]}")
# Out:
# ------ dwarf ---------
# Clue: organism, Weight: 2.0
# Clue: person, Weight: 2.0
# Clue: living, Weight: 2.0
# Clue: mythical, Weight: 2.0
# Clue: biped, Weight: 2.0
# Clue: animal, Weight: 2.0
# Clue: short, Weight: 2.0
# Clue: small, Weight: 2.0
# Clue: human, Weight: 2.0
# Clue: sentient, Weight: 2.0
# Clue: stunt, Weight: 2.0
# Clue: creature, Weight: 1.8
# Clue: race, Weight: 1.8
# Clue: thing, Weight: 1.8
# Clue: system, Weight: 1.8
# Clue: homo, Weight: 1.8
# Clue: category, Weight: 1.8
# Clue: causal, Weight: 1.8
# Clue: complex, Weight: 1.8
# Clue: member, Weight: 1.8
# Clue: legal, Weight: 1.8
# Clue: individual, Weight: 1.8
# Clue: sapien, Weight: 1.8
# Clue: body, Weight: 1.8
# Clue: social, Weight: 1.8
# Clue: grammatical, Weight: 1.8
# Clue: Living, Weight: 1.8
# Clue: people, Weight: 1.8
# Clue: legged, Weight: 1.8
# Clue: genus, Weight: 1.8
# Clue: diplont, Weight: 1.8
# Clue: heterotroph, Weight: 1.8
# Clue: object, Weight: 1.8
# Clue: non, Weight: 1.8
# Clue: preditor, Weight: 1.8
# Clue: perceptual, Weight: 1.8
# Clue: artifactual, Weight: 1.8
# Clue: part, Weight: 1.8
# Clue: embodied, Weight: 1.8
# Clue: solid, Weight: 1.8
# Clue: eukaryotic, Weight: 1.8
# Clue: primitive, Weight: 1.8
# Clue: computer, Weight: 1.8
# Clue: variable, Weight: 1.8
# Clue: code, Weight: 1.8
# Clue: tract, Weight: 1.8
# Clue: type, Weight: 1.8
# Clue: size, Weight: 1.8
# Clue: hypocrit, Weight: 1.8
# Clue: morally, Weight: 1.8
# Clue: primate, Weight: 1.8
# Clue: fallible, Weight: 1.8
# Clue: scale, Weight: 1.8
# Clue: metres, Weight: 1.8
# Clue: synonym, Weight: 1.8
# Clue: hypocrites, Weight: 1.8
# Clue: impede, Weight: 1.8
# Clue: perform, Weight: 1.8
# Clue: kook, Weight: 1.6400000000000001
# Clue: applicant, Weight: 1.6400000000000001
# Clue: soldier, Weight: 1.6400000000000001
# Clue: scientist, Weight: 1.6400000000000001
# Clue: manipulator, Weight: 1.6400000000000001
# Clue: slave, Weight: 1.6400000000000001
# Clue: unfortunate, Weight: 1.6400000000000001
# Clue: third, Weight: 1.6400000000000001
# Clue: alien, Weight: 1.6400000000000001
# Clue: captor, Weight: 1.6400000000000001
# Clue: mad, Weight: 1.6400000000000001
# Clue: rater, Weight: 1.6400000000000001
# Clue: bird, Weight: 1.6400000000000001
# Clue: snowman, Weight: 1.6400000000000001
# Clue: abominable, Weight: 1.6400000000000001
# Clue: gnome, Weight: 1.6400000000000001
# Clue: ardipithecus, Weight: 1.6400000000000001
# Clue: ape, Weight: 1.6400000000000001
# Clue: chicken, Weight: 1.6400000000000001
# Clue: kangaroo, Weight: 1.6400000000000001
# Clue: great, Weight: 1.6400000000000001
# Clue: rhinoceros, Weight: 1.6400000000000001
# Clue: fish, Weight: 1.6400000000000001
# Clue: marmot, Weight: 1.6400000000000001
# Clue: rabbit, Weight: 1.6400000000000001
# Clue: pet, Weight: 1.6400000000000001
# Clue: dolphin, Weight: 1.6400000000000001
# Clue: worm, Weight: 1.6400000000000001
# Clue: lion, Weight: 1.6400000000000001
# Clue: fox, Weight: 1.6400000000000001
# Clue: articles, Weight: 1.6400000000000001
# Clue: Magazine, Weight: 1.6400000000000001
# Clue: nap, Weight: 1.6400000000000001
# Clue: mon, Weight: 1.6400000000000001
# Clue: width, Weight: 1.6400000000000001
# Clue: black, Weight: 1.6400000000000001
# Clue: aborigine, Weight: 1.6400000000000001
# Clue: shoe, Weight: 1.6400000000000001
# Clue: ethnic, Weight: 1.6400000000000001
# Clue: magar, Weight: 1.6400000000000001
# Clue: terrorist, Weight: 1.6400000000000001
# Clue: kashmiri, Weight: 1.6400000000000001
# Clue: caucasian, Weight: 1.6400000000000001
# Clue: khmer, Weight: 1.6400000000000001
# Clue: australian, Weight: 1.6400000000000001
# Clue: kanembou, Weight: 1.6400000000000001
# Clue: haired, Weight: 1.6400000000000001
# Clue: auburn, Weight: 1.6400000000000001
# Clue: eee, Weight: 1.6400000000000001
# Clue: supernatural, Weight: 1.6400000000000001
# Clue: gold, Weight: 1.6
# Clue: goldemar, Weight: 1.6
# Clue: monopod, Weight: 1.6
# Clue: mine, Weight: 1.6
# Clue: little, Weight: 1.6
# Clue: king, Weight: 1.6
# Clue: indefinite, Weight: 1.6
# Clue: quantity, Weight: 1.6
# Clue: face, Weight: 1.6
# Clue: country, Weight: 1.6
# Clue: checker, Weight: 1.6
# Clue: card, Weight: 1.6
# Clue: royalty, Weight: 1.6
# Clue: chess, Weight: 1.6
# Clue: sovereign, Weight: 1.6
# Clue: ruler, Weight: 1.6
# Clue: male, Weight: 1.6
# Clue: piece, Weight: 1.6
# Clue: chessman, Weight: 1.6
# Clue: eminence, Weight: 1.6
# Clue: created, Weight: 1.6
# Clue: entity, Weight: 1.6
# Clue: aerobe, Weight: 1.512
# Clue: parasite, Weight: 1.512
# Clue: parent, Weight: 1.512
# Clue: diploid, Weight: 1.512
# Clue: eukaryoyte, Weight: 1.512
# Clue: plant, Weight: 1.512
# Clue: zooid, Weight: 1.512
# Clue: haploid, Weight: 1.512
# Clue: turn, Weight: 1.5
# Clue: scandinavian, Weight: 1.5
# Clue: crafting, Weight: 1.5
# Clue: insignificant, Weight: 1.5
# Clue: puny, Weight: 1.5
# Clue: render, Weight: 1.5
# Clue: lots, Weight: 1.4400000000000002
# Clue: money, Weight: 1.4400000000000002
# Clue: cost, Weight: 1.4400000000000002
# Clue: explode, Weight: 1.4400000000000002
# Clue: world, Weight: 1.4400000000000002
# Clue: clients, Weight: 1.4400000000000002
# Clue: Communication, Weight: 1.4400000000000002
# Clue: France, Weight: 1.4400000000000002
# Clue: Great, Weight: 1.4400000000000002
# Clue: Britain, Weight: 1.4400000000000002
# Clue: King, Weight: 1.4400000000000002
# Clue: Germans, Weight: 1.4400000000000002
# Clue: insect, Weight: 1.4400000000000002
# Clue: leprechaun, Weight: 1.4400000000000002
# Clue: mermaid, Weight: 1.4400000000000002
# Clue: fisher, Weight: 1.4400000000000002
# Clue: hippocampus, Weight: 1.4400000000000002
# ------ foot ---------
# Clue: measurement, Weight: 2.0
# Clue: walk, Weight: 2.0
# Clue: unit, Weight: 2.0
# Clue: secret, Weight: 2.0
# Clue: vertebrate, Weight: 2.0
# Clue: part, Weight: 2.0
# Clue: body, Weight: 2.0
# Clue: linear, Weight: 2.0
# Clue: bottom, Weight: 2.0
# Clue: support, Weight: 2.0
# Clue: human, Weight: 2.0
# Clue: organ, Weight: 2.0
# Clue: pay, Weight: 2.0
# Clue: add, Weight: 2.0
# Clue: running, Weight: 1.8
# Clue: Walking, Weight: 1.8
# Clue: walking, Weight: 1.8
# Clue: supporting, Weight: 1.8
# Clue: people, Weight: 1.8
# Clue: things, Weight: 1.8
# Clue: socks, Weight: 1.8
# Clue: stand, Weight: 1.8
# Clue: Keeping, Weight: 1.8
# Clue: Putting, Weight: 1.8
# Clue: movement, Weight: 1.8
# Clue: upright, Weight: 1.8
# Clue: objects, Weight: 1.8
# Clue: measuring, Weight: 1.8
# Clue: standing, Weight: 1.8
# Clue: activity, Weight: 1.8
# Clue: gait, Weight: 1.8
# Clue: carriage, Weight: 1.8
# Clue: path, Weight: 1.8
# Clue: turn, Weight: 1.8
# Clue: locomotion, Weight: 1.8
# Clue: travel, Weight: 1.8
# Clue: whole, Weight: 1.8
# Clue: television, Weight: 1.8
# Clue: show, Weight: 1.8
# Clue: organization, Weight: 1.8
# Clue: side, Weight: 1.8
# Clue: thing, Weight: 1.8
# Clue: system, Weight: 1.8
# Clue: deodorant, Weight: 1.8
# Clue: information, Weight: 1.8
# Clue: book, Weight: 1.8
# Clue: going, Weight: 1.8
# Clue: organism, Weight: 1.8
# Clue: object, Weight: 1.8
# Clue: symmetric, Weight: 1.8
# Clue: bilaterally, Weight: 1.8
# Clue: scale, Weight: 1.8
# Clue: animal, Weight: 1.8
# Clue: sentient, Weight: 1.8
# Clue: hexalateral, Weight: 1.8
# Clue: multicellular, Weight: 1.8
# Clue: chordate, Weight: 1.8
# Clue: region, Weight: 1.8
# Clue: section, Weight: 1.8
# Clue: ear, Weight: 1.8
# Clue: concern, Weight: 1.8
# Clue: concept, Weight: 1.8
# Clue: tune, Weight: 1.8
# Clue: tangible, Weight: 1.8
# Clue: line, Weight: 1.8
# Clue: relation, Weight: 1.8
# Clue: structure, Weight: 1.8
# Clue: person, Weight: 1.8
# Clue: missing, Weight: 1.8
# Clue: mass, Weight: 1.8
# Clue: group, Weight: 1.8
# Clue: natural, Weight: 1.8
# Clue: message, Weight: 1.8
# Clue: social, Weight: 1.8
# Clue: posession, Weight: 1.8
# Clue: work, Weight: 1.8
# Clue: good, Weight: 1.8
# Clue: form, Weight: 1.8
# Clue: cargo, Weight: 1.8
# Clue: quark, Weight: 1.8
# Clue: ship, Weight: 1.8
# Clue: resource, Weight: 1.8
# Clue: influence, Weight: 1.8
# Clue: operation, Weight: 1.8
# Clue: aid, Weight: 1.8
# Clue: device, Weight: 1.8
# Clue: cubicle, Weight: 1.8
# Clue: likely, Weight: 1.8
# Clue: dangerous, Weight: 1.8
# Clue: evil, Weight: 1.8
# Clue: life, Weight: 1.8
# Clue: wind, Weight: 1.8
# Clue: instument, Weight: 1.8
# Clue: kind, Weight: 1.8
# Clue: musical, Weight: 1.8
# Clue: agency, Weight: 1.8
# Clue: keyboard, Weight: 1.8
# Clue: periodical, Weight: 1.8
# Clue: insrrument, Weight: 1.8
# Clue: instrument, Weight: 1.8
# Clue: coffin, Weight: 1.8
# Clue: rising, Weight: 1.8
# Clue: requite, Weight: 1.8
# Clue: make, Weight: 1.8
# Clue: settle, Weight: 1.8
# Clue: give, Weight: 1.8
# Clue: digest, Weight: 1.8
# Clue: calculate, Weight: 1.8
# Clue: increase, Weight: 1.8
# Clue: state, Weight: 1.8
# Clue: traverse, Weight: 1.8
# Clue: behave, Weight: 1.8
# Clue: accompany, Weight: 1.8
# Clue: pace, Weight: 1.8
# Clue: score, Weight: 1.8
# Clue: consociate, Weight: 1.8
# Clue: compel, Weight: 1.8
# Clue: play, Weight: 1.8
# Clue: toes, Weight: 1.7
# Clue: yard, Weight: 1.7
# Clue: shoe, Weight: 1.7
# Clue: desk, Weight: 1.7
# Clue: inches, Weight: 1.7
# Clue: table, Weight: 1.7
# Clue: boot, Weight: 1.7
# Clue: sock, Weight: 1.7
# Clue: grave, Weight: 1.7
# Clue: toe, Weight: 1.6400000000000001
# Clue: mileage, Weight: 1.6400000000000001
# Clue: pelvimetry, Weight: 1.6400000000000001
# Clue: anthropometry, Weight: 1.6400000000000001
# Clue: Time, Weight: 1.6400000000000001
# Clue: calorimetry, Weight: 1.6400000000000001
# Clue: actinometry, Weight: 1.6400000000000001
# Clue: ohm, Weight: 1.6400000000000001
# Clue: tablespoon, Weight: 1.6400000000000001
# Clue: sounding, Weight: 1.6400000000000001
# Clue: shamble, Weight: 1.6400000000000001
# Clue: wading, Weight: 1.6400000000000001
# Clue: ambulatory, Weight: 1.6400000000000001
# Clue: march, Weight: 1.6400000000000001
# Clue: ambulation, Weight: 1.6400000000000001
# Clue: team, Weight: 1.6400000000000001
# Clue: family, Weight: 1.6400000000000001
# Clue: company, Weight: 1.6400000000000001
# Clue: instrumentality, Weight: 1.6400000000000001
# Clue: couple, Weight: 1.6400000000000001
# Clue: member, Weight: 1.6400000000000001
# Clue: outfit, Weight: 1.6400000000000001
# Clue: esoterica, Weight: 1.6400000000000001
# Clue: password, Weight: 1.6400000000000001
# Clue: confidence, Weight: 1.6400000000000001
# Clue: cabala, Weight: 1.6400000000000001
# Clue: bird, Weight: 1.6400000000000001
# Clue: amniote, Weight: 1.6400000000000001
# Clue: reptile, Weight: 1.6400000000000001
# Clue: mammal, Weight: 1.6400000000000001
# Clue: tetrapod, Weight: 1.6400000000000001
# Clue: Amniota, Weight: 1.6400000000000001
# Clue: fetus, Weight: 1.6400000000000001
# Clue: amphibian, Weight: 1.6400000000000001
# Clue: gnathostome, Weight: 1.6400000000000001
# Clue: chukka, Weight: 1.6400000000000001
# Clue: acicula, Weight: 1.6400000000000001
# Clue: butt, Weight: 1.6400000000000001
# Clue: quarter, Weight: 1.6400000000000001
# Clue: item, Weight: 1.6400000000000001
# Clue: cutting, Weight: 1.6400000000000001
# Clue: neck, Weight: 1.6400000000000001
# Clue: backbone, Weight: 1.6400000000000001
# Clue: back, Weight: 1.6400000000000001
# Clue: university, Weight: 1.6400000000000001
# Clue: college, Weight: 1.6400000000000001
# Clue: school, Weight: 1.6400000000000001
# Clue: electoral, Weight: 1.6400000000000001
# Clue: immigration, Weight: 1.6400000000000001
# Clue: particle, Weight: 1.6400000000000001
# Clue: church, Weight: 1.6400000000000001
# Clue: corps, Weight: 1.6400000000000001
# Clue: heel, Weight: 1.6400000000000001
# Clue: base, Weight: 1.6400000000000001
# Clue: underbelly, Weight: 1.6400000000000001
# Clue: sole, Weight: 1.6400000000000001
# Clue: bilge, Weight: 1.6400000000000001
# Clue: rib, Weight: 1.6400000000000001
# Clue: stirrup, Weight: 1.6400000000000001
# Clue: handrest, Weight: 1.6400000000000001
# Clue: yoke, Weight: 1.6400000000000001
# Clue: perch, Weight: 1.6400000000000001
# Clue: bracket, Weight: 1.6400000000000001
# Clue: bearing, Weight: 1.6400000000000001
# Clue: harp, Weight: 1.6400000000000001
# Clue: structural, Weight: 1.6400000000000001
# Clue: maintenance, Weight: 1.6400000000000001
# Clue: lawyers, Weight: 1.6400000000000001
# Clue: ladies, Weight: 1.6400000000000001
# Clue: Cleaning, Weight: 1.6400000000000001
# Clue: nick, Weight: 1.6400000000000001
# Clue: wing, Weight: 1.6400000000000001
# Clue: ctene, Weight: 1.6400000000000001
# Clue: brain, Weight: 1.6400000000000001
# Clue: kick, Weight: 1.6400000000000001
# Clue: redeem, Weight: 1.6400000000000001
# Clue: tithe, Weight: 1.6400000000000001
# Clue: spend, Weight: 1.6400000000000001
# Clue: compensate, Weight: 1.6400000000000001
# Clue: prefer, Weight: 1.6400000000000001
# Clue: toss, Weight: 1.6400000000000001
# Clue: button, Weight: 1.6400000000000001
# Clue: butylate, Weight: 1.6400000000000001
# Clue: intercalate, Weight: 1.6400000000000001
# Clue: supplement, Weight: 1.6400000000000001
# Clue: enrich, Weight: 1.6400000000000001
# Clue: milk, Weight: 1.6400000000000001
# Clue: inject, Weight: 1.6400000000000001
# Clue: welt, Weight: 1.6400000000000001
# Clue: stalk, Weight: 1.6400000000000001
# Clue: amble, Weight: 1.6400000000000001
# Clue: stumble, Weight: 1.6400000000000001
# Clue: flounce, Weight: 1.6400000000000001
# Clue: slink, Weight: 1.6400000000000001
# Clue: tread, Weight: 1.6400000000000001
# Clue: parade, Weight: 1.6400000000000001
# Clue: toddle, Weight: 1.6400000000000001
# Clue: promenade, Weight: 1.6400000000000001
# Clue: getting, Weight: 1.62
# Clue: obtaining, Weight: 1.62
# Clue: Running, Weight: 1.62
# Clue: muggers, Weight: 1.62
# Clue: fun, Weight: 1.62
# Clue: away, Weight: 1.62
# Clue: influencing, Weight: 1.62
# Clue: somewhere, Weight: 1.62
# Clue: fast, Weight: 1.62
# Clue: losing, Weight: 1.62
# Clue: office, Weight: 1.62
# Clue: weight, Weight: 1.62
# Clue: exercise, Weight: 1.62
# Clue: voters, Weight: 1.62
# Clue: police, Weight: 1.62
# Clue: escaping, Weight: 1.62
# Clue: concerts, Weight: 1.62
# Clue: teach, Weight: 1.62
# Clue: socializing, Weight: 1.62
# Clue: labor, Weight: 1.62
# Clue: fighting, Weight: 1.62
# Clue: talk, Weight: 1.62
# Clue: exploitation, Weight: 1.62
# Clue: attending, Weight: 1.62
# Clue: cold, Weight: 1.62
# Clue: cover, Weight: 1.62
# Clue: smelly, Weight: 1.62
# Clue: Socks, Weight: 1.62
# Clue: looking, Weight: 1.62
# Clue: health, Weight: 1.62
# Clue: enemies, Weight: 1.62
# Clue: moving, Weight: 1.62
# Clue: nature, Weight: 1.62
# Clue: places, Weight: 1.62
# Clue: place, Weight: 1.62
# Clue: ground, Weight: 1.6
# Clue: step, Weight: 1.6
# Clue: mile, Weight: 1.6
# Clue: paw, Weight: 1.6
# Clue: head, Weight: 1.6
# Clue: share, Weight: 1.6
# Clue: piece, Weight: 1.6
# Clue: portion, Weight: 1.6
# Clue: component, Weight: 1.6
# Clue: bit, Weight: 1.6
# Clue: legs, Weight: 1.6
# Clue: physical, Weight: 1.6
# Clue: corpse, Weight: 1.6
# Clue: torso, Weight: 1.6
# Clue: arms, Weight: 1.6
# Clue: touch, Weight: 1.6
# Clue: parent, Weight: 1.6
# Clue: handle, Weight: 1.6
# Clue: outside, Weight: 1.53
# Clue: housing, Weight: 1.53
# Clue: city, Weight: 1.53
# Clue: house, Weight: 1.53
# Clue: property, Weight: 1.53
# Clue: subdivision, Weight: 1.53
# Clue: Michigan, Weight: 1.53
# Clue: neighborhood, Weight: 1.53
# Clue: development, Weight: 1.53
# Clue: drawer, Weight: 1.53
# Clue: smart, Weight: 1.53
# Clue: left, Weight: 1.53
# Clue: ad, Weight: 1.53
# Clue: store, Weight: 1.53
# Clue: Nike, Weight: 1.53
# Clue: asses, Weight: 1.53
# Clue: smartasses, Weight: 1.53
# Clue: closet, Weight: 1.53
# Clue: locker, Weight: 1.53
# Clue: garage, Weight: 1.53
# Clue: study, Weight: 1.53
# Clue: furniture, Weight: 1.53
# Clue: sale, Weight: 1.53
# Clue: schoolroom, Weight: 1.53
# Clue: building, Weight: 1.53
# Clue: bedroom, Weight: 1.53
# Clue: home, Weight: 1.53
# Clue: library, Weight: 1.53
# Clue: motel, Weight: 1.53
# Clue: den, Weight: 1.53
# Clue: apartment, Weight: 1.53
# Clue: rug, Weight: 1.53
# Clue: room, Weight: 1.53
# Clue: demonstration, Weight: 1.53
# Clue: dining, Weight: 1.53
# Clue: corner, Weight: 1.53
# Clue: resturant, Weight: 1.53
# Clue: kitchen, Weight: 1.53
# Clue: conference, Weight: 1.53
# Clue: chest, Weight: 1.53
# Clue: drawers, Weight: 1.53
# Clue: funeral, Weight: 1.53
# Clue: artery, Weight: 1.52
# Clue: vein, Weight: 1.52
# Clue: arteries, Weight: 1.52
# Clue: instep, Weight: 1.52
# Clue: inch, Weight: 1.52
# Clue: digital, Weight: 1.52
# Clue: little, Weight: 1.52
# Clue: metatarsal, Weight: 1.52
# Clue: intercapitular, Weight: 1.52
# Clue: arcuate, Weight: 1.52
# Clue: big, Weight: 1.52
# Clue: circulatory, Weight: 1.52
# Clue: footwear, Weight: 1.52
# Clue: hoof, Weight: 1.52
# Clue: golf, Weight: 1.52
# Clue: club, Weight: 1.52
# Clue: stocking, Weight: 1.52
# Clue: skeleton, Weight: 1.52
# Clue: metatarsus, Weight: 1.52
# Clue: appendage, Weight: 1.5
# Clue: leg, Weight: 1.5
# Clue: used, Weight: 1.5
# Clue: take, Weight: 1.5
# Clue: required, Weight: 1.5
# Clue: verse, Weight: 1.48
# Clue: eye, Weight: 1.48
# Clue: nose, Weight: 1.48
# Clue: hand, Weight: 1.48
# Clue: branch, Weight: 1.48
# Clue: bone, Weight: 1.48
# Clue: dance, Weight: 1.48
# Clue: blood, Weight: 1.48
# Clue: Spike, Weight: 1.476
# Clue: early, Weight: 1.476
# Clue: stadium, Weight: 1.476
# Clue: Legs, Weight: 1.476
# Clue: track, Weight: 1.476
# Clue: run, Weight: 1.476
# Clue: platform, Weight: 1.476
# Clue: suspension, Weight: 1.476
# Clue: cable, Weight: 1.476
# Clue: clock, Weight: 1.476
# Clue: political, Weight: 1.476
# Clue: first, Weight: 1.476
# Clue: sofa, Weight: 1.476
# Clue: class, Weight: 1.476
# Clue: airline, Weight: 1.476
# Clue: dinner, Weight: 1.476
# Clue: seat, Weight: 1.476
# Clue: ideology, Weight: 1.476
# Clue: exhibits, Weight: 1.476
# Clue: seeing, Weight: 1.476
# Clue: eating, Weight: 1.476
# Clue: chair, Weight: 1.476
# Clue: dancing, Weight: 1.476
# Clue: conversation, Weight: 1.476
# Clue: satchel, Weight: 1.476
# Clue: street, Weight: 1.476
# Clue: isle, Weight: 1.476
# Clue: evening, Weight: 1.476
# Clue: aisle, Weight: 1.476
# Clue: riding, Weight: 1.476
# Clue: horse, Weight: 1.476
# Clue: teaspoon, Weight: 1.476
# Clue: ruler, Weight: 1.476
# Clue: caliper, Weight: 1.476
# Clue: cup, Weight: 1.476
# Clue: adding, Weight: 1.476
# Clue: stone, Weight: 1.476
# Clue: laser, Weight: 1.476
# Clue: numbers, Weight: 1.476
# Clue: stop, Weight: 1.476
# Clue: subway, Weight: 1.476
# Clue: covering, Weight: 1.4500000000000002
# Clue: clothing, Weight: 1.4500000000000002
# Clue: laces, Weight: 1.4500000000000002
# Clue: wear, Weight: 1.4500000000000002
# Clue: freeze, Weight: 1.4400000000000002
# Clue: winter, Weight: 1.4400000000000002
# ------ moon ---------
# Clue: Moon, Weight: 2.0
# Clue: kilometres, Weight: 2.0
# Clue: uninhabited, Weight: 2.0
# Clue: big, Weight: 2.0
# Clue: cold, Weight: 2.0
# Clue: earth, Weight: 2.0
# Clue: sphere, Weight: 2.0
# Clue: craters, Weight: 2.0
# Clue: satellite, Weight: 2.0
# Clue: sattelite, Weight: 2.0
# Clue: beautiful, Weight: 2.0
# Clue: place, Weight: 2.0
# Clue: radiant, Weight: 2.0
# Clue: object, Weight: 2.0
# Clue: pits, Weight: 2.0
# Clue: planet, Weight: 2.0
# Clue: smaller, Weight: 2.0
# Clue: full, Weight: 2.0
# Clue: Earth, Weight: 2.0
# Clue: year, Weight: 2.0
# Clue: astronomical, Weight: 2.0
# Clue: idle, Weight: 2.0
# Clue: expose, Weight: 2.0
# Clue: surface, Weight: 1.8
# Clue: rock, Weight: 1.8
# Clue: body, Weight: 1.8
# Clue: circle, Weight: 1.8
# Clue: station, Weight: 1.8
# Clue: spheroidal, Weight: 1.8
# Clue: globe, Weight: 1.8
# Clue: environment, Weight: 1.8
# Clue: geometric, Weight: 1.8
# Clue: dimensional, Weight: 1.8
# Clue: shape, Weight: 1.8
# Clue: artifact, Weight: 1.8
# Clue: geographical, Weight: 1.8
# Clue: solid, Weight: 1.8
# Clue: spheroid, Weight: 1.8
# Clue: round, Weight: 1.8
# Clue: area, Weight: 1.8
# Clue: Sun, Weight: 1.8
# Clue: old, Weight: 1.8
# Clue: unit, Weight: 1.8
# Clue: sphereoid, Weight: 1.8
# Clue: years, Weight: 1.8
# Clue: word, Weight: 1.8
# Clue: oblate, Weight: 1.8
# Clue: element, Weight: 1.8
# Clue: heat, Weight: 1.8
# Clue: spacecraft, Weight: 1.8
# Clue: computer, Weight: 1.8
# Clue: toshiba, Weight: 1.8
# Clue: electronic, Weight: 1.8
# Clue: follower, Weight: 1.8
# Clue: celestial, Weight: 1.8
# Clue: solar, Weight: 1.8
# Clue: equipment, Weight: 1.8
# Clue: laptop, Weight: 1.8
# Clue: heavenly, Weight: 1.8
# Clue: device, Weight: 1.8
# Clue: powered, Weight: 1.8
# Clue: stifling, Weight: 1.8
# Clue: brisk, Weight: 1.8
# Clue: item, Weight: 1.8
# Clue: situation, Weight: 1.8
# Clue: vicinity, Weight: 1.8
# Clue: somewhere, Weight: 1.8
# Clue: cognition, Weight: 1.8
# Clue: condition, Weight: 1.8
# Clue: go, Weight: 1.8
# Clue: Place, Weight: 1.8
# Clue: passage, Weight: 1.8
# Clue: social, Weight: 1.8
# Clue: type, Weight: 1.8
# Clue: thing, Weight: 1.8
# Clue: science, Weight: 1.8
# Clue: content, Weight: 1.8
# Clue: physical, Weight: 1.8
# Clue: composite, Weight: 1.8
# Clue: entity, Weight: 1.8
# Clue: constituent, Weight: 1.8
# Clue: noun, Weight: 1.8
# Clue: spherical, Weight: 1.8
# Clue: count, Weight: 1.8
# Clue: matter, Weight: 1.8
# Clue: planemo, Weight: 1.8
# Clue: large, Weight: 1.8
# Clue: planetary, Weight: 1.8
# Clue: collection, Weight: 1.8
# Clue: abandon, Weight: 1.8
# Clue: show, Weight: 1.8
# Clue: subject, Weight: 1.8
# Clue: air, Weight: 1.7
# Clue: gravity, Weight: 1.7
# Clue: cratered, Weight: 1.7
# Clue: mild, Weight: 1.7
# Clue: outerspace, Weight: 1.7
# Clue: space, Weight: 1.7
# Clue: sides, Weight: 1.7
# Clue: outer, Weight: 1.7
# Clue: many, Weight: 1.7
# Clue: universe, Weight: 1.7
# Clue: freezing, Weight: 1.6800000000000002
# Clue: effect, Weight: 1.6800000000000002
# Clue: sun, Weight: 1.6400000000000001
# Clue: formation, Weight: 1.6400000000000001
# Clue: store, Weight: 1.6400000000000001
# Clue: haystack, Weight: 1.6400000000000001
# Clue: elephants, Weight: 1.6400000000000001
# Clue: arenas, Weight: 1.6400000000000001
# Clue: sharks, Weight: 1.6400000000000001
# Clue: whale, Weight: 1.6400000000000001
# Clue: department, Weight: 1.6400000000000001
# Clue: rain, Weight: 1.6400000000000001
# Clue: receive, Weight: 1.6400000000000001
# Clue: clouds, Weight: 1.6400000000000001
# Clue: front, Weight: 1.6400000000000001
# Clue: distaff, Weight: 1.6400000000000001
# Clue: conglomeration, Weight: 1.6400000000000001
# Clue: ball, Weight: 1.6400000000000001
# Clue: arena, Weight: 1.6400000000000001
# Clue: preserve, Weight: 1.6400000000000001
# Clue: lap, Weight: 1.6400000000000001
# Clue: political, Weight: 1.6400000000000001
# Clue: inner, Weight: 1.6400000000000001
# Clue: planets, Weight: 1.6400000000000001
# Clue: moraine, Weight: 1.6400000000000001
# Clue: saprolite, Weight: 1.6400000000000001
# Clue: soil, Weight: 1.6400000000000001
# Clue: morning, Weight: 1.6400000000000001
# Clue: sputnik, Weight: 1.6400000000000001
# Clue: pole, Weight: 1.6400000000000001
# Clue: north, Weight: 1.6400000000000001
# Clue: temperatures, Weight: 1.6400000000000001
# Clue: winters, Weight: 1.6400000000000001
# Clue: ice, Weight: 1.6400000000000001
# Clue: vinyl, Weight: 1.6400000000000001
# Clue: river, Weight: 1.6400000000000001
# Clue: winter, Weight: 1.6400000000000001
# Clue: Canada, Weight: 1.6400000000000001
# Clue: Space, Weight: 1.6400000000000001
# Clue: lacks, Weight: 1.6400000000000001
# Clue: water, Weight: 1.6400000000000001
# Clue: deserts, Weight: 1.6400000000000001
# Clue: think, Weight: 1.6400000000000001
# Clue: Water, Weight: 1.6400000000000001
# Clue: fireworks, Weight: 1.6400000000000001
# Clue: Colour, Weight: 1.6400000000000001
# Clue: people, Weight: 1.6400000000000001
# Clue: dangerous, Weight: 1.6400000000000001
# Clue: mother, Weight: 1.6400000000000001
# Clue: things, Weight: 1.6400000000000001
# Clue: lakes, Weight: 1.6400000000000001
# Clue: simple, Weight: 1.6400000000000001
# Clue: light, Weight: 1.6400000000000001
# Clue: art, Weight: 1.6400000000000001
# Clue: Simple, Weight: 1.6400000000000001
# Clue: countryside, Weight: 1.6400000000000001
# Clue: bar, Weight: 1.6400000000000001
# Clue: bed, Weight: 1.6400000000000001
# Clue: college, Weight: 1.6400000000000001
# Clue: city, Weight: 1.6400000000000001
# Clue: Hawaii, Weight: 1.6400000000000001
# Clue: living, Weight: 1.6400000000000001
# Clue: gym, Weight: 1.6400000000000001
# Clue: pub, Weight: 1.6400000000000001
# Clue: University, Weight: 1.6400000000000001
# Clue: room, Weight: 1.6400000000000001
# Clue: Solar, Weight: 1.6400000000000001
# Clue: energy, Weight: 1.6400000000000001
# Clue: part, Weight: 1.6400000000000001
# Clue: fomite, Weight: 1.6400000000000001
# Clue: commodity, Weight: 1.6400000000000001
# Clue: head, Weight: 1.6400000000000001
# Clue: tool, Weight: 1.6400000000000001
# Clue: dart, Weight: 1.6400000000000001
# Clue: pen, Weight: 1.6400000000000001
# Clue: triviality, Weight: 1.6400000000000001
# Clue: keepsake, Weight: 1.6400000000000001
# Clue: geological, Weight: 1.6400000000000001
# Clue: Neptune, Weight: 1.6400000000000001
# Clue: Mars, Weight: 1.6400000000000001
# Clue: saturn, Weight: 1.6400000000000001
# Clue: Uranus, Weight: 1.6400000000000001
# Clue: Jupiter, Weight: 1.6400000000000001
# Clue: Venus, Weight: 1.6400000000000001
# Clue: Mercury, Weight: 1.6400000000000001
# Clue: indicates, Weight: 1.6400000000000001
# Clue: opposite, Weight: 1.6400000000000001
# Clue: empty, Weight: 1.6400000000000001
# Clue: overflow, Weight: 1.6400000000000001
# Clue: bethlehem, Weight: 1.6400000000000001
# Clue: lie, Weight: 1.6400000000000001
# Clue: daydream, Weight: 1.6400000000000001
# Clue: bum, Weight: 1.6400000000000001
# Clue: ride, Weight: 1.6400000000000001
# Clue: bench, Weight: 1.6400000000000001
# Clue: flaunt, Weight: 1.6400000000000001
# Clue: model, Weight: 1.6400000000000001
# Clue: hold, Weight: 1.6400000000000001
# Clue: eclipses, Weight: 1.6
# Clue: secondary, Weight: 1.6
# Clue: days, Weight: 1.6
# Clue: shine, Weight: 1.6
# Clue: quarter, Weight: 1.6
# Clue: country, Weight: 1.6
# Clue: made, Weight: 1.6
# Clue: construct, Weight: 1.6
# Clue: office, Weight: 1.6
# Clue: jurisdiction, Weight: 1.6
# Clue: man, Weight: 1.6
# Clue: grammatical, Weight: 1.6
# Clue: influence, Weight: 1.6
# Clue: path, Weight: 1.6
# Clue: apparatus, Weight: 1.6
# Clue: third, Weight: 1.6
# Clue: ground, Weight: 1.6
# Clue: dirt, Weight: 1.6
# Clue: world, Weight: 1.6
# Clue: orbit, Weight: 1.6
# Clue: neptune, Weight: 1.6
# Clue: mercury, Weight: 1.6
# Clue: uranus, Weight: 1.6
# Clue: Belinda, Weight: 1.544
# Clue: Kim, Weight: 1.544
# Clue: Harry, Weight: 1.544
# Clue: sky, Weight: 1.53
# Clue: shuttle, Weight: 1.53
# Clue: house, Weight: 1.53
# Clue: jar, Weight: 1.53
# Clue: bridge, Weight: 1.53
# Clue: train, Weight: 1.53
# Clue: balloon, Weight: 1.53
# Clue: cupboard, Weight: 1.53
# Clue: supermarket, Weight: 1.53
# Clue: Gravity, Weight: 1.53
# Clue: lot, Weight: 1.53
# Clue: back, Weight: 1.53
# Clue: sentence, Weight: 1.53
# Clue: box, Weight: 1.53
# Clue: mall, Weight: 1.53
# Clue: parking, Weight: 1.53
# Clue: suitcase, Weight: 1.53
# Clue: Many, Weight: 1.53
# Clue: night, Weight: 1.5
# Clue: seen, Weight: 1.5
# Clue: day, Weight: 1.5
# Clue: sometimes, Weight: 1.5
# Clue: lunar, Weight: 1.5
# Clue: system, Weight: 1.48
# Clue: positioning, Weight: 1.48
# Clue: satelloid, Weight: 1.48
# Clue: view, Weight: 1.48
# Clue: global, Weight: 1.48
# Clue: pay, Weight: 1.48
# Clue: geo, Weight: 1.48
# Clue: land, Weight: 1.48
# Clue: pluto, Weight: 1.476
# Clue: atmosphere, Weight: 1.4500000000000002
# Clue: vacuum, Weight: 1.4500000000000002
# Clue: dogs, Weight: 1.4400000000000002
# Clue: cats, Weight: 1.4400000000000002
# Clue: laundry, Weight: 1.4400000000000002
# Clue: dry, Weight: 1.4400000000000002
# Clue: brightly, Weight: 1.4400000000000002
# Clue: skin, Weight: 1.4400000000000002
# Clue: brown, Weight: 1.4400000000000002
# Clue: rise, Weight: 1.4400000000000002
# Clue: burn, Weight: 1.4400000000000002
# Clue: age, Weight: 1.4400000000000002
# Clue: human, Weight: 1.4400000000000002
# Clue: bright, Weight: 1.4400000000000002
# ------ star ---------
# Clue: ball, Weight: 2.0
# Clue: convex, Weight: 2.0
# Clue: burning, Weight: 2.0
# Clue: thing, Weight: 2.0
# Clue: figure, Weight: 2.0
# Clue: gas, Weight: 2.0
# Clue: body, Weight: 2.0
# Clue: sun, Weight: 2.0
# Clue: celestial, Weight: 2.0
# Clue: plane, Weight: 2.0
# Clue: shape, Weight: 2.0
# Clue: actor, Weight: 2.0
# Clue: pretty, Weight: 2.0
# Clue: perform, Weight: 2.0
# Clue: mark, Weight: 2.0
# Clue: mass, Weight: 1.8
# Clue: guidance, Weight: 1.8
# Clue: system, Weight: 1.8
# Clue: boat, Weight: 1.8
# Clue: excellence, Weight: 1.8
# Clue: navigate, Weight: 1.8
# Clue: recognizing, Weight: 1.8
# Clue: earth, Weight: 1.8
# Clue: -, Weight: 1.8
# Clue: toy, Weight: 1.8
# Clue: golfer, Weight: 1.8
# Clue: sphere, Weight: 1.8
# Clue: teste, Weight: 1.8
# Clue: game, Weight: 1.8
# Clue: slang, Weight: 1.8
# Clue: name, Weight: 1.8
# Clue: equipment, Weight: 1.8
# Clue: term, Weight: 1.8
# Clue: dance, Weight: 1.8
# Clue: hit, Weight: 1.8
# Clue: agglomeration, Weight: 1.8
# Clue: pitch, Weight: 1.8
# Clue: thermal, Weight: 1.8
# Clue: Burning, Weight: 1.8
# Clue: conversion, Weight: 1.8
# Clue: decomposition, Weight: 1.8
# Clue: situation, Weight: 1.8
# Clue: extreme, Weight: 1.8
# Clue: change, Weight: 1.8
# Clue: punishment, Weight: 1.8
# Clue: event, Weight: 1.8
# Clue: chemical, Weight: 1.8
# Clue: execution, Weight: 1.8
# Clue: process, Weight: 1.8
# Clue: reaction, Weight: 1.8
# Clue: torture, Weight: 1.8
# Clue: energy, Weight: 1.8
# Clue: integrity, Weight: 1.8
# Clue: capital, Weight: 1.8
# Clue: aim, Weight: 1.8
# Clue: statement, Weight: 1.8
# Clue: object, Weight: 1.8
# Clue: attribute, Weight: 1.8
# Clue: artifact, Weight: 1.8
# Clue: abstraction, Weight: 1.8
# Clue: happening, Weight: 1.8
# Clue: action, Weight: 1.8
# Clue: physical, Weight: 1.8
# Clue: entity, Weight: 1.8
# Clue: natural, Weight: 1.8
# Clue: sum, Weight: 1.8
# Clue: model, Weight: 1.8
# Clue: illustration, Weight: 1.8
# Clue: maneuver, Weight: 1.8
# Clue: representation, Weight: 1.8
# Clue: impression, Weight: 1.8
# Clue: percept, Weight: 1.8
# Clue: substance, Weight: 1.8
# Clue: fluid, Weight: 1.8
# Clue: inanimate, Weight: 1.8
# Clue: state, Weight: 1.8
# Clue: matter, Weight: 1.8
# Clue: form, Weight: 1.8
# Clue: Gas, Weight: 1.8
# Clue: structure, Weight: 1.8
# Clue: person, Weight: 1.8
# Clue: missing, Weight: 1.8
# Clue: ear, Weight: 1.8
# Clue: group, Weight: 1.8
# Clue: message, Weight: 1.8
# Clue: social, Weight: 1.8
# Clue: posession, Weight: 1.8
# Clue: heat, Weight: 1.8
# Clue: Sun, Weight: 1.8
# Clue: major, Weight: 1.8
# Clue: orbited, Weight: 1.8
# Clue: bigger, Weight: 1.8
# Clue: Earth, Weight: 1.8
# Clue: important, Weight: 1.8
# Clue: source, Weight: 1.8
# Clue: setting, Weight: 1.8
# Clue: surface, Weight: 1.8
# Clue: machine, Weight: 1.8
# Clue: tool, Weight: 1.8
# Clue: vehicle, Weight: 1.8
# Clue: geometry, Weight: 1.8
# Clue: power, Weight: 1.8
# Clue: hand, Weight: 1.8
# Clue: degree, Weight: 1.8
# Clue: edge, Weight: 1.8
# Clue: spatial, Weight: 1.8
# Clue: property, Weight: 1.8
# Clue: geometric, Weight: 1.8
# Clue: magazine, Weight: 1.8
# Clue: concretism, Weight: 1.8
# Clue: artist, Weight: 1.8
# Clue: interpetor, Weight: 1.8
# Clue: musical, Weight: 1.8
# Clue: performer, Weight: 1.8
# Clue: performing, Weight: 1.8
# Clue: act, Weight: 1.8
# Clue: re, Weight: 1.8
# Clue: create, Weight: 1.8
# Clue: bespeak, Weight: 1.8
# Clue: sky, Weight: 1.7
# Clue: center, Weight: 1.7
# Clue: much, Weight: 1.7
# Clue: planet, Weight: 1.7
# Clue: outerspace, Weight: 1.7
# Clue: galaxy, Weight: 1.7
# Clue: space, Weight: 1.7
# Clue: heavens, Weight: 1.7
# Clue: cluster, Weight: 1.7
# Clue: night, Weight: 1.7
# Clue: hole, Weight: 1.7
# Clue: outer, Weight: 1.7
# Clue: solar, Weight: 1.7
# Clue: globular, Weight: 1.7
# Clue: black, Weight: 1.7
# Clue: promenade, Weight: 1.6400000000000001
# Clue: globule, Weight: 1.6400000000000001
# Clue: ignition, Weight: 1.6400000000000001
# Clue: class, Weight: 1.6400000000000001
# Clue: incineration, Weight: 1.6400000000000001
# Clue: internal, Weight: 1.6400000000000001
# Clue: bonfire, Weight: 1.6400000000000001
# Clue: fire, Weight: 1.6400000000000001
# Clue: combustion, Weight: 1.6400000000000001
# Clue: campfire, Weight: 1.6400000000000001
# Clue: auto, Weight: 1.6400000000000001
# Clue: arson, Weight: 1.6400000000000001
# Clue: stinker, Weight: 1.6400000000000001
# Clue: blanket, Weight: 1.6400000000000001
# Clue: flagship, Weight: 1.6400000000000001
# Clue: unit, Weight: 1.6400000000000001
# Clue: freshener, Weight: 1.6400000000000001
# Clue: pill, Weight: 1.6400000000000001
# Clue: security, Weight: 1.6400000000000001
# Clue: snorter, Weight: 1.6400000000000001
# Clue: heaven, Weight: 1.6400000000000001
# Clue: jimdandy, Weight: 1.6400000000000001
# Clue: appear, Weight: 1.6400000000000001
# Clue: dummy, Weight: 1.6400000000000001
# Clue: puppet, Weight: 1.6400000000000001
# Clue: octagon, Weight: 1.6400000000000001
# Clue: spread, Weight: 1.6400000000000001
# Clue: eagle, Weight: 1.6400000000000001
# Clue: figurine, Weight: 1.6400000000000001
# Clue: parallel, Weight: 1.6400000000000001
# Clue: triangle, Weight: 1.6400000000000001
# Clue: back, Weight: 1.6400000000000001
# Clue: Helium, Weight: 1.6400000000000001
# Clue: dioxide, Weight: 1.6400000000000001
# Clue: oxygen, Weight: 1.6400000000000001
# Clue: nitrogen, Weight: 1.6400000000000001
# Clue: exhaust, Weight: 1.6400000000000001
# Clue: chlorine, Weight: 1.6400000000000001
# Clue: Air, Weight: 1.6400000000000001
# Clue: inhalant, Weight: 1.6400000000000001
# Clue: steam, Weight: 1.6400000000000001
# Clue: ozone, Weight: 1.6400000000000001
# Clue: university, Weight: 1.6400000000000001
# Clue: college, Weight: 1.6400000000000001
# Clue: school, Weight: 1.6400000000000001
# Clue: electoral, Weight: 1.6400000000000001
# Clue: immigration, Weight: 1.6400000000000001
# Clue: particle, Weight: 1.6400000000000001
# Clue: church, Weight: 1.6400000000000001
# Clue: corps, Weight: 1.6400000000000001
# Clue: sidereal, Weight: 1.6400000000000001
# Clue: jointer, Weight: 1.6400000000000001
# Clue: circle, Weight: 1.6400000000000001
# Clue: concavity, Weight: 1.6400000000000001
# Clue: square, Weight: 1.6400000000000001
# Clue: straightness, Weight: 1.6400000000000001
# Clue: rectangle, Weight: 1.6400000000000001
# Clue: dullness, Weight: 1.6400000000000001
# Clue: roundness, Weight: 1.6400000000000001
# Clue: angularity, Weight: 1.6400000000000001
# Clue: scene, Weight: 1.6400000000000001
# Clue: comedian, Weight: 1.6400000000000001
# Clue: energizer, Weight: 1.6400000000000001
# Clue: beaver, Weight: 1.6400000000000001
# Clue: man, Weight: 1.6400000000000001
# Clue: leading, Weight: 1.6400000000000001
# Clue: mime, Weight: 1.6400000000000001
# Clue: walk, Weight: 1.6400000000000001
# Clue: powerhouse, Weight: 1.6400000000000001
# Clue: kilmer, Weight: 1.6400000000000001
# Clue: val, Weight: 1.6400000000000001
# Clue: stealer, Weight: 1.6400000000000001
# Clue: eager, Weight: 1.6400000000000001
# Clue: watch, Weight: 1.6400000000000001
# Clue: People, Weight: 1.6400000000000001
# Clue: fountain, Weight: 1.6400000000000001
# Clue: rainbow, Weight: 1.6400000000000001
# Clue: flowers, Weight: 1.6400000000000001
# Clue: new, Weight: 1.6400000000000001
# Clue: like, Weight: 1.6400000000000001
# Clue: song, Weight: 1.6400000000000001
# Clue: diamonds, Weight: 1.6400000000000001
# Clue: Snowflakes, Weight: 1.6400000000000001
# Clue: courtyard, Weight: 1.6400000000000001
# Clue: lead, Weight: 1.6400000000000001
# Clue: stunt, Weight: 1.6400000000000001
# Clue: declaim, Weight: 1.6400000000000001
# Clue: audition, Weight: 1.6400000000000001
# Clue: play, Weight: 1.6400000000000001
# Clue: solo, Weight: 1.6400000000000001
# Clue: underline, Weight: 1.6400000000000001
# Clue: tip, Weight: 1.6400000000000001
# Clue: blaze, Weight: 1.6400000000000001
# Clue: dimension, Weight: 1.6400000000000001
# Clue: stigmatize, Weight: 1.6400000000000001
# Clue: trace, Weight: 1.6400000000000001
# Clue: striate, Weight: 1.6400000000000001
# Clue: speck, Weight: 1.6400000000000001
# Clue: bespot, Weight: 1.6400000000000001
# Clue: raddle, Weight: 1.6400000000000001
# Clue: water, Weight: 1.62
# Clue: sailing, Weight: 1.62
# Clue: travel, Weight: 1.62
# Clue: skiing, Weight: 1.62
# Clue: watersports, Weight: 1.62
# Clue: fishing, Weight: 1.62
# Clue: floating, Weight: 1.62
# Clue: capsize, Weight: 1.62
# Clue: cross, Weight: 1.62
# Clue: transport, Weight: 1.62
# Clue: hexagram, Weight: 1.6
# Clue: red, Weight: 1.6
# Clue: giant, Weight: 1.6
# Clue: explode, Weight: 1.6
# Clue: asterism, Weight: 1.6
# Clue: supernova, Weight: 1.6
# Clue: shine, Weight: 1.6
# Clue: traveler, Weight: 1.6
# Clue: weary, Weight: 1.6
# Clue: film, Weight: 1.6
# Clue: guide, Weight: 1.6
# Clue: equilateral, Weight: 1.6
# Clue: shaped, Weight: 1.6
# Clue: dodecagon, Weight: 1.6
# Clue: color, Weight: 1.6
# Clue: colour, Weight: 1.6
# Clue: primary, Weight: 1.6
# Clue: mythical, Weight: 1.6
# Clue: region, Weight: 1.6
# Clue: explosion, Weight: 1.6
# Clue: exploding, Weight: 1.6
# Clue: astronomical, Weight: 1.6
# Clue: chromatic, Weight: 1.6
# Clue: passion, Weight: 1.6
# Clue: colored, Weight: 1.6
# Clue: acolor, Weight: 1.6
# Clue: Red, Weight: 1.6
# Clue: luxury, Weight: 1.6
# Clue: animal, Weight: 1.6
# Clue: tall, Weight: 1.6
# Clue: sentient, Weight: 1.6
# Clue: imaginary, Weight: 1.6
# Clue: enterprise, Weight: 1.6
# Clue: large, Weight: 1.6
# Clue: painting, Weight: 1.53
# Clue: photo, Weight: 1.53
# Clue: day, Weight: 1.53
# Clue: schoolers, Weight: 1.53
# Clue: atmosphere, Weight: 1.53
# Clue: pre, Weight: 1.53
# Clue: place, Weight: 1.53
# Clue: planetarium, Weight: 1.53
# Clue: outdoors, Weight: 1.53
# Clue: hong, Weight: 1.53
# Clue: kong, Weight: 1.53
# Clue: universe, Weight: 1.53
# Clue: lot, Weight: 1.53
# Clue: shuttle, Weight: 1.53
# Clue: jar, Weight: 1.53
# Clue: sentence, Weight: 1.53
# Clue: box, Weight: 1.53
# Clue: mall, Weight: 1.53
# Clue: parking, Weight: 1.53
# Clue: suitcase, Weight: 1.53
# Clue: shop, Weight: 1.53
# Clue: nature, Weight: 1.53
# Clue: human, Weight: 1.53
# Clue: computer, Weight: 1.53
# Clue: house, Weight: 1.53
# Clue: store, Weight: 1.53
# Clue: pipes, Weight: 1.53
# Clue: science, Weight: 1.53
# Clue: old, Weight: 1.53
# Clue: notebook, Weight: 1.53
# Clue: course, Weight: 1.53
# Clue: golf, Weight: 1.53
# Clue: swiss, Weight: 1.53
# Clue: dirt, Weight: 1.53
# Clue: button, Weight: 1.53
# Clue: wall, Weight: 1.53
# Clue: donut, Weight: 1.53
# Clue: pocket, Weight: 1.53
# Clue: sock, Weight: 1.53
# Clue: ground, Weight: 1.53
# Clue: paper, Weight: 1.53
# Clue: cheese, Weight: 1.53
# Clue: hotel, Weight: 1.5
# Clue: combustible, Weight: 1.5
# Clue: seen, Weight: 1.5
# Clue: astronomy, Weight: 1.5
# Clue: russia, Weight: 1.5
# Clue: blue, Weight: 1.4900000000000002
# Clue: purple, Weight: 1.4900000000000002
# Clue: evening, Weight: 1.4900000000000002
# Clue: dark, Weight: 1.4900000000000002
# Clue: rain, Weight: 1.4900000000000002
# Clue: ugly, Weight: 1.4900000000000002
# Clue: becomes, Weight: 1.4900000000000002
# Clue: starry, Weight: 1.4900000000000002
# Clue: thunderheads, Weight: 1.4900000000000002
# Clue: beautiful, Weight: 1.4900000000000002
# Clue: gray, Weight: 1.4900000000000002
# Clue: looks, Weight: 1.4900000000000002
# Clue: storm, Weight: 1.4900000000000002
# Clue: minister, Weight: 1.476
# Clue: book, Weight: 1.476
# Clue: railing, Weight: 1.476
# Clue: mast, Weight: 1.476
# Clue: underground, Weight: 1.476
# Clue: landmark, Weight: 1.476
# Clue: map, Weight: 1.476
# Clue: vessel, Weight: 1.476
# Clue: spheroid, Weight: 1.4500000000000002
# Clue: orbit, Weight: 1.4500000000000002
# Clue: neptune, Weight: 1.4500000000000002
# Clue: uranus, Weight: 1.4500000000000002
# Clue: mercury, Weight: 1.4500000000000002
# Clue: Star, Weight: 1.4400000000000002
# Clue: David, Weight: 1.4400000000000002
# Clue: hypernova, Weight: 1.4400000000000002
# Clue: ship, Weight: 1.4400000000000002
# Clue: original, Weight: 1.4400000000000002
# Clue: train, Weight: 1.4400000000000002
# Clue: borrow, Weight: 1.4400000000000002
# Clue: credit, Weight: 1.4400000000000002
# Clue: destination, Weight: 1.4400000000000002
# Clue: cards, Weight: 1.4400000000000002
# Clue: board, Weight: 1.4400000000000002
# Clue: return, Weight: 1.4400000000000002
# Clue: journey, Weight: 1.4400000000000002
# Clue: liner, Weight: 1.4400000000000002
# Clue: far, Weight: 1.4400000000000002
# Clue: sub, Weight: 1.4400000000000002
# Clue: money, Weight: 1.4400000000000002
# Clue: coat, Weight: 1.4400000000000002
# Clue: scarlet, Weight: 1.4400000000000002
# Clue: cerise, Weight: 1.4400000000000002
# Clue: crimson, Weight: 1.4400000000000002
# Clue: ruby, Weight: 1.4400000000000002
# Clue: cardinal, Weight: 1.4400000000000002
# Clue: sanguine, Weight: 1.4400000000000002
# Clue: pharmaceutical, Weight: 1.4400000000000002
# Clue: Argus, Weight: 1.4400000000000002
# Clue: Jotunn, Weight: 1.4400000000000002
# Clue: Mimir, Weight: 1.4400000000000002
# Clue: Cyclops, Weight: 1.4400000000000002
# Clue: industry, Weight: 1.4400000000000002
# Clue: ogre, Weight: 1.4400000000000002
# Clue: views, Weight: 1.4400000000000002
# Clue: teach, Weight: 1.4400000000000002
# Clue: features, Weight: 1.4400000000000002
# Clue: cathedral, Weight: 1.4400000000000002
# Clue: tourist, Weight: 1.4400000000000002
# Clue: follower, Weight: 1.4400000000000002
# Clue: right, Weight: 1.4400000000000002
# Clue: direction, Weight: 1.4400000000000002
# Clue: show, Weight: 1.4400000000000002
# Clue: point, Weight: 1.4400000000000002
# Clue: best, Weight: 1.4400000000000002
# Clue: museum, Weight: 1.4400000000000002
# Clue: scenic, Weight: 1.4400000000000002
# Clue: ginger, Weight: 1.4000000000000001
# Clue: blood, Weight: 1.4000000000000001
# Clue: snooker, Weight: 1.4000000000000001
# Clue: communist, Weight: 1.4000000000000001
# Clue: huge, Weight: 1.4000000000000001
# Clue: jotun, Weight: 1.4000000000000001
# Clue: packet, Weight: 1.4000000000000001
# Clue: ethernet, Weight: 1.4000000000000001
# ------ ghost ---------
# Clue: apparition, Weight: 2.0
# Clue: mythical, Weight: 2.0
# Clue: non, Weight: 2.0
# Clue: artifactual, Weight: 2.0
# Clue: soul, Weight: 2.0
# Clue: costume, Weight: 2.0
# Clue: spirit, Weight: 2.0
# Clue: intangible, Weight: 2.0
# Clue: halloween, Weight: 2.0
# Clue: popular, Weight: 2.0
# Clue: disembodied, Weight: 2.0
# Clue: supernatural, Weight: 2.0
# Clue: author, Weight: 2.0
# Clue: travel, Weight: 2.0
# Clue: appearance, Weight: 1.8
# Clue: illusion, Weight: 1.8
# Clue: living, Weight: 1.8
# Clue: spark, Weight: 1.8
# Clue: embodiment, Weight: 1.8
# Clue: feeling, Weight: 1.8
# Clue: Soul, Weight: 1.8
# Clue: black, Weight: 1.8
# Clue: gospel, Weight: 1.8
# Clue: music, Weight: 1.8
# Clue: God, Weight: 1.8
# Clue: attire, Weight: 1.8
# Clue: beverages, Weight: 1.8
# Clue: liquid, Weight: 1.8
# Clue: atmosphere, Weight: 1.8
# Clue: alcoholic, Weight: 1.8
# Clue: spiritual, Weight: 1.8
# Clue: vital, Weight: 1.8
# Clue: Spirit, Weight: 1.8
# Clue: principle, Weight: 1.8
# Clue: class, Weight: 1.8
# Clue: character, Weight: 1.8
# Clue: assets, Weight: 1.8
# Clue: thing, Weight: 1.8
# Clue: partially, Weight: 1.8
# Clue: calendar, Weight: 1.8
# Clue: holiday, Weight: 1.8
# Clue: gregorian, Weight: 1.8
# Clue: observance, Weight: 1.8
# Clue: Halloween, Weight: 1.8
# Clue: pagan, Weight: 1.8
# Clue: causal, Weight: 1.8
# Clue: season, Weight: 1.8
# Clue: television, Weight: 1.8
# Clue: write, Weight: 1.8
# Clue: unidentified, Weight: 1.6400000000000001
# Clue: flying, Weight: 1.6400000000000001
# Clue: Flying, Weight: 1.6400000000000001
# Clue: object, Weight: 1.6400000000000001
# Clue: Dutchman, Weight: 1.6400000000000001
# Clue: inside, Weight: 1.6400000000000001
# Clue: find, Weight: 1.6400000000000001
# Clue: santa, Weight: 1.6400000000000001
# Clue: rigout, Weight: 1.6400000000000001
# Clue: dress, Weight: 1.6400000000000001
# Clue: drag, Weight: 1.6400000000000001
# Clue: suit, Weight: 1.6400000000000001
# Clue: fancy, Weight: 1.6400000000000001
# Clue: genie, Weight: 1.6400000000000001
# Clue: kachina, Weight: 1.6400000000000001
# Clue: cowardice, Weight: 1.6400000000000001
# Clue: zombi, Weight: 1.6400000000000001
# Clue: presence, Weight: 1.6400000000000001
# Clue: banshee, Weight: 1.6400000000000001
# Clue: python, Weight: 1.6400000000000001
# Clue: Zeitgeist, Weight: 1.6400000000000001
# Clue: atemporal, Weight: 1.6400000000000001
# Clue: good, Weight: 1.6400000000000001
# Clue: mathematical, Weight: 1.6400000000000001
# Clue: mind, Weight: 1.6400000000000001
# Clue: spatial, Weight: 1.6400000000000001
# Clue: heart, Weight: 1.6400000000000001
# Clue: computational, Weight: 1.6400000000000001
# Clue: tram, Weight: 1.6400000000000001
# Clue: lance, Weight: 1.6400000000000001
# Clue: ease, Weight: 1.6400000000000001
# Clue: whistle, Weight: 1.6400000000000001
# Clue: float, Weight: 1.6400000000000001
# Clue: walk, Weight: 1.6400000000000001
# Clue: circle, Weight: 1.6400000000000001
# Clue: island, Weight: 1.6400000000000001
# Clue: voyage, Weight: 1.6400000000000001
# Clue: hop, Weight: 1.6400000000000001
# Clue: nowhere, Weight: 1.6
# Clue: poltergeist, Weight: 1.6
# Clue: alive, Weight: 1.6
# Clue: late, Weight: 1.6
# Clue: revenant, Weight: 1.6
# Clue: appear, Weight: 1.6
# Clue: night, Weight: 1.6
# Clue: surprise, Weight: 1.6
# Clue: death, Weight: 1.6
# Clue: person, Weight: 1.6
# Clue: appearing, Weight: 1.6
# Clue: Casper, Weight: 1.6
# Clue: haunt, Weight: 1.6
# Clue: roller, Weight: 1.6
# Clue: coaster, Weight: 1.6
# Clue: game, Weight: 1.6
# Clue: video, Weight: 1.6
# Clue: mirage, Weight: 1.5
# Clue: barghest, Weight: 1.5
# Clue: lemur, Weight: 1.5
# Clue: pale, Weight: 1.5
# Clue: route, Weight: 1.5
# Clue: wisp, Weight: 1.5
# Clue: client, Weight: 1.5
# Clue: warning, Weight: 1.5
# Clue: sail, Weight: 1.5
# Clue: grow, Weight: 1.4400000000000002
# Clue: suicide, Weight: 1.4400000000000002
# Clue: homicide, Weight: 1.4400000000000002
# Clue: Death, Weight: 1.4400000000000002
# Clue: murder, Weight: 1.4400000000000002
# Clue: iron, Weight: 1.4400000000000002
# Clue: cold, Weight: 1.4400000000000002
# Clue: cross, Weight: 1.4400000000000002
# Clue: joke, Weight: 1.4400000000000002
# Clue: wind, Weight: 1.4400000000000002
# Clue: board, Weight: 1.4400000000000002
# Clue: opinion, Weight: 1.4400000000000002
# Clue: clock, Weight: 1.4400000000000002
# Clue: plane, Weight: 1.4400000000000002
# Clue: wave, Weight: 1.4400000000000002
# Clue: street, Weight: 1.4400000000000002
# Clue: voice, Weight: 1.4400000000000002
# Clue: plant, Weight: 1.4400000000000002
# Clue: catch, Weight: 1.4400000000000002
# Clue: water, Weight: 1.4400000000000002
# Clue: thank, Weight: 1.4400000000000002
# Clue: shirt, Weight: 1.4400000000000002
# Clue: friend, Weight: 1.4400000000000002
# Clue: laugh, Weight: 1.4400000000000002
# Clue: stalk, Weight: 1.4000000000000001
# Clue: practise, Weight: 1.4000000000000001
# Clue: habitation, Weight: 1.4000000000000001
# Clue: inhabit, Weight: 1.4000000000000001
# Clue: restless, Weight: 1.4000000000000001
# Clue: hangout, Weight: 1.4000000000000001
# Clue: habituate, Weight: 1.4000000000000001
# Clue: uneasy, Weight: 1.4000000000000001
# ------ beijing ---------
# Clue: locomotive, Weight: 2.0
# Clue: Beijing, Weight: 2.0
# Clue: place, Weight: 1.8
# Clue: humans, Weight: 1.8
# Clue: wheeled, Weight: 1.8
# Clue: self, Weight: 1.8
# Clue: propelled, Weight: 1.8
# Clue: occupied, Weight: 1.8
# Clue: fuel, Weight: 1.8
# Clue: land, Weight: 1.8
# Clue: vehicle, Weight: 1.8
# Clue: device, Weight: 1.8
# Clue: powered, Weight: 1.8
# Clue: Overpopulation, Weight: 1.7680000000000002
# Clue: food, Weight: 1.7680000000000002
# Clue: chain, Weight: 1.7680000000000002
# Clue: fast, Weight: 1.7680000000000002
# Clue: horse, Weight: 1.6400000000000001
# Clue: shunter, Weight: 1.6400000000000001
# Clue: -, Weight: 1.6400000000000001
# Clue: iron, Weight: 1.6400000000000001
# Clue: pilot, Weight: 1.6400000000000001
# Clue: choo, Weight: 1.6400000000000001
# Clue: tank, Weight: 1.6400000000000001
# Clue: traction, Weight: 1.6400000000000001
# Clue: engine, Weight: 1.6400000000000001
# Clue: dinky, Weight: 1.6400000000000001
# Clue: switch, Weight: 1.6400000000000001
# Clue: capital, Weight: 1.6
# Clue: China, Weight: 1.6
# Clue: assets, Weight: 1.6
# Clue: government, Weight: 1.6
# Clue: top, Weight: 1.6
# Clue: resides, Weight: 1.6
# Clue: center, Weight: 1.6
# Clue: Capital, Weight: 1.6
# Clue: seat, Weight: 1.6
# Clue: city, Weight: 1.6
# Clue: character, Weight: 1.6
# Clue: fridge, Weight: 1.564
# Clue: pantry, Weight: 1.564
# Clue: stomach, Weight: 1.564
# Clue: cupboard, Weight: 1.564
# Clue: supermarket, Weight: 1.564
# Clue: oven, Weight: 1.564
# Clue: table, Weight: 1.564
# Clue: refrigerator, Weight: 1.564
# Clue: Food, Weight: 1.564
# Clue: kitchen, Weight: 1.564
# Clue: shift, Weight: 1.564
# Clue: garage, Weight: 1.564
# Clue: tow, Weight: 1.564
# Clue: hardware, Weight: 1.564
# Clue: truck, Weight: 1.564
# Clue: bicycle, Weight: 1.564
# Clue: dungeon, Weight: 1.564
# Clue: gear, Weight: 1.564
# Clue: store, Weight: 1.564
# Clue: locked, Weight: 1.564
# Clue: motorbike, Weight: 1.564
# Clue: shed, Weight: 1.564
# Clue: gate, Weight: 1.564
# Clue: jewerly, Weight: 1.564
# Clue: Forbidden, Weight: 1.52
# Clue: City, Weight: 1.52
# Clue: east, Weight: 1.52
# Clue: asia, Weight: 1.52
# Clue: East, Weight: 1.52
# Clue: Asia, Weight: 1.52
# Clue: republic, Weight: 1.5
# Clue: people, Weight: 1.5
# Clue: china, Weight: 1.5
# Clue: money, Weight: 1.4400000000000002
# Clue: stock, Weight: 1.4400000000000002
# Clue: seed, Weight: 1.4400000000000002
# Clue: principal, Weight: 1.4400000000000002
# Clue: endowment, Weight: 1.4400000000000002
# Clue: storage, Weight: 1.4280000000000002
# Clue: freezer, Weight: 1.4280000000000002
# Clue: salt, Weight: 1.4280000000000002
# Clue: container, Weight: 1.4280000000000002
# Clue: restaurant, Weight: 1.4280000000000002
# Clue: hair, Weight: 1.4280000000000002
# Clue: crab, Weight: 1.4280000000000002
# Clue: fungus, Weight: 1.4280000000000002
# Clue: grape, Weight: 1.4280000000000002
# Clue: meat, Weight: 1.4280000000000002
# Clue: area, Weight: 1.4280000000000002
# Clue: potato, Weight: 1.4280000000000002
# ------ fighter ---------
# Clue: airplane, Weight: 2.0
# Clue: film, Weight: 2.0
# Clue: warplane, Weight: 2.0
# Clue: combat, Weight: 1.8
# Clue: aircraft, Weight: 1.8
# Clue: machine, Weight: 1.8
# Clue: wings, Weight: 1.8
# Clue: transportation, Weight: 1.8
# Clue: displaces, Weight: 1.8
# Clue: wing, Weight: 1.8
# Clue: heavier, Weight: 1.8
# Clue: fuel, Weight: 1.8
# Clue: craft, Weight: 1.8
# Clue: vehicle, Weight: 1.8
# Clue: fixed, Weight: 1.8
# Clue: large, Weight: 1.8
# Clue: form, Weight: 1.8
# Clue: air, Weight: 1.8
# Clue: device, Weight: 1.8
# Clue: powered, Weight: 1.8
# Clue: region, Weight: 1.8
# Clue: expression, Weight: 1.8
# Clue: sheet, Weight: 1.8
# Clue: object, Weight: 1.8
# Clue: surface, Weight: 1.8
# Clue: paper, Weight: 1.8
# Clue: finite, Weight: 1.8
# Clue: photographic, Weight: 1.8
# Clue: artistic, Weight: 1.8
# Clue: wrapping, Weight: 1.8
# Clue: medium, Weight: 1.8
# Clue: Film, Weight: 1.8
# Clue: military, Weight: 1.8
# Clue: bomber, Weight: 1.6400000000000001
# Clue: delta, Weight: 1.6400000000000001
# Clue: airliner, Weight: 1.6400000000000001
# Clue: -, Weight: 1.6400000000000001
# Clue: jet, Weight: 1.6400000000000001
# Clue: ski, Weight: 1.6400000000000001
# Clue: seaplane, Weight: 1.6400000000000001
# Clue: monoplane, Weight: 1.6400000000000001
# Clue: reconnaissance, Weight: 1.6400000000000001
# Clue: queen, Weight: 1.6400000000000001
# Clue: hangar, Weight: 1.6400000000000001
# Clue: amphibian, Weight: 1.6400000000000001
# Clue: plane, Weight: 1.6400000000000001
# Clue: slick, Weight: 1.6400000000000001
# Clue: scum, Weight: 1.6400000000000001
# Clue: silver, Weight: 1.6400000000000001
# Clue: positive, Weight: 1.6400000000000001
# Clue: negative, Weight: 1.6400000000000001
# Clue: movie, Weight: 1.6400000000000001
# Clue: screen, Weight: 1.6400000000000001
# Clue: fight, Weight: 1.6
# Clue: well, Weight: 1.6
# Clue: kamikaze, Weight: 1.6
# Clue: opponent, Weight: 1.6
# Clue: box, Weight: 1.6
# Clue: bout, Weight: 1.6
# Clue: best, Weight: 1.6
# Clue: punch, Weight: 1.6
# Clue: strike, Weight: 1.6
# Clue: ear, Weight: 1.6
# Clue: lose, Weight: 1.6
# Clue: duck, Weight: 1.6
# Clue: interceptor, Weight: 1.6
# Clue: cauliflower, Weight: 1.6
# Clue: pilot, Weight: 1.6
# Clue: suicide, Weight: 1.6
# Clue: physical, Weight: 1.5
# Clue: soldier, Weight: 1.5
# Clue: combatant, Weight: 1.5
# Clue: boxer, Weight: 1.5
# Clue: adversity, Weight: 1.5
# Clue: pugnacious, Weight: 1.5
# Clue: school, Weight: 1.4400000000000002
# Clue: result, Weight: 1.4400000000000002
# Clue: suspension, Weight: 1.4400000000000002
# Clue: goose, Weight: 1.4400000000000002
# Clue: deal, Weight: 1.4400000000000002
# Clue: skeletons, Weight: 1.4400000000000002
# Clue: blow, Weight: 1.4400000000000002
# Clue: dig, Weight: 1.4400000000000002
# Clue: cook, Weight: 1.4400000000000002
# Clue: food, Weight: 1.4400000000000002
# Clue: things, Weight: 1.4400000000000002
# Clue: objects, Weight: 1.4400000000000002
# Clue: store, Weight: 1.4400000000000002
# Clue: catch, Weight: 1.4400000000000002
# Clue: secret, Weight: 1.4400000000000002
# Clue: clothes, Weight: 1.4400000000000002
# Clue: hold, Weight: 1.4400000000000002
# Clue: ball, Weight: 1.4400000000000002
# Clue: stuff, Weight: 1.4400000000000002
# Clue: hole, Weight: 1.4400000000000002
# Clue: create, Weight: 1.4400000000000002
# Clue: knock, Weight: 1.4400000000000002
# Clue: wood, Weight: 1.4400000000000002
# Clue: teeth, Weight: 1.4400000000000002
# Clue: impulses, Weight: 1.4400000000000002
# Clue: convert, Weight: 1.4400000000000002
# Clue: waves, Weight: 1.4400000000000002
# Clue: infected, Weight: 1.4400000000000002
# Clue: hear, Weight: 1.4400000000000002
# Clue: nerve, Weight: 1.4400000000000002
# Clue: sound, Weight: 1.4400000000000002
# Clue: become, Weight: 1.4400000000000002
# Clue: mother, Weight: 1.4400000000000002
# Clue: ducklings, Weight: 1.4400000000000002
# Clue: argue, Weight: 1.4000000000000001
# Clue: brawl, Weight: 1.4000000000000001
# Clue: quarrel, Weight: 1.4000000000000001
# Clue: altercation, Weight: 1.4000000000000001
# Clue: argument, Weight: 1.4000000000000001
# Clue: boxing, Weight: 1.4000000000000001
# Clue: action, Weight: 1.4000000000000001
# Clue: conflict, Weight: 1.4000000000000001
# Clue: battle, Weight: 1.4000000000000001
# ------ roulette ---------
# Clue: chance, Weight: 2.0
# Clue: game, Weight: 2.0
# Clue: curve, Weight: 2.0
# Clue: wheel, Weight: 2.0
# Clue: risk, Weight: 1.8
# Clue: activity, Weight: 1.8
# Clue: meat, Weight: 1.8
# Clue: contest, Weight: 1.8
# Clue: occupation, Weight: 1.8
# Clue: animal, Weight: 1.8
# Clue: part, Weight: 1.8
# Clue: equipment, Weight: 1.8
# Clue: score, Weight: 1.8
# Clue: play, Weight: 1.8
# Clue: magazine, Weight: 1.8
# Clue: line, Weight: 1.8
# Clue: pitch, Weight: 1.8
# Clue: force, Weight: 1.8
# Clue: car, Weight: 1.8
# Clue: machine, Weight: 1.8
# Clue: helm, Weight: 1.8
# Clue: object, Weight: 1.8
# Clue: radial, Weight: 1.8
# Clue: spin, Weight: 1.8
# Clue: bicycle, Weight: 1.8
# Clue: shaped, Weight: 1.8
# Clue: circular, Weight: 1.8
# Clue: round, Weight: 1.8
# Clue: thing, Weight: 1.8
# Clue: casino, Weight: 1.7
# Clue: hockey, Weight: 1.6400000000000001
# Clue: sport, Weight: 1.6400000000000001
# Clue: polo, Weight: 1.6400000000000001
# Clue: football, Weight: 1.6400000000000001
# Clue: Polo, Weight: 1.6400000000000001
# Clue: Zork, Weight: 1.6400000000000001
# Clue: Tennis, Weight: 1.6400000000000001
# Clue: water, Weight: 1.6400000000000001
# Clue: Baseball, Weight: 1.6400000000000001
# Clue: jax, Weight: 1.6400000000000001
# Clue: Chess, Weight: 1.6400000000000001
# Clue: Cupid, Weight: 1.6400000000000001
# Clue: helix, Weight: 1.6400000000000001
# Clue: scallop, Weight: 1.6400000000000001
# Clue: bell, Weight: 1.6400000000000001
# Clue: crescent, Weight: 1.6400000000000001
# Clue: sinuosity, Weight: 1.6400000000000001
# Clue: regression, Weight: 1.6400000000000001
# Clue: arch, Weight: 1.6400000000000001
# Clue: envelope, Weight: 1.6400000000000001
# Clue: bow, Weight: 1.6400000000000001
# Clue: wave, Weight: 1.6400000000000001
# Clue: roller, Weight: 1.6400000000000001
# Clue: rowel, Weight: 1.6400000000000001
# Clue: tire, Weight: 1.6400000000000001
# Clue: hypocycloid, Weight: 1.6
# Clue: epicycloid, Weight: 1.6
# Clue: cycloid, Weight: 1.6
# Clue: decorate, Weight: 1.5
# Clue: mezzotint, Weight: 1.5
# Clue: curler, Weight: 1.5
# Clue: stamp, Weight: 1.5
# Clue: incision, Weight: 1.5
# Clue: hair, Weight: 1.5
# Clue: locus, Weight: 1.5
# Clue: cardioid, Weight: 1.4400000000000002
# Clue: epicycle, Weight: 1.4000000000000001
# Clue: point, Weight: 1.4000000000000001
# Clue: circumference, Weight: 1.4000000000000001
# Clue: roll, Weight: 1.4000000000000001
# Clue: slip, Weight: 1.4000000000000001
# Clue: spirograph, Weight: 1.4000000000000001
# Clue: circle, Weight: 1.4000000000000001
# Clue: astroid, Weight: 1.4000000000000001
# ------ alps ---------
# Clue: europe, Weight: 2.0
# Clue: mountain, Weight: 2.0
# Clue: range, Weight: 2.0
# Clue: magazine, Weight: 1.8
# Clue: continent, Weight: 1.8
# Clue: Europe, Weight: 1.8
# Clue: eurasia, Weight: 1.8
# Clue: station, Weight: 1.8
# Clue: vertical, Weight: 1.8
# Clue: place, Weight: 1.8
# Clue: kilometres, Weight: 1.8
# Clue: topographical, Weight: 1.8
# Clue: elevation, Weight: 1.8
# Clue: object, Weight: 1.8
# Clue: exhausting, Weight: 1.8
# Clue: scale, Weight: 1.8
# Clue: thing, Weight: 1.8
# Clue: protrusion, Weight: 1.8
# Clue: molehill, Weight: 1.8
# Clue: hare, Weight: 1.8
# Clue: larger, Weight: 1.8
# Clue: natural, Weight: 1.8
# Clue: large, Weight: 1.8
# Clue: sport, Weight: 1.8
# Clue: climbed, Weight: 1.8
# Clue: hill, Weight: 1.8
# Clue: formation, Weight: 1.8
# Clue: set, Weight: 1.8
# Clue: geological, Weight: 1.8
# Clue: tract, Weight: 1.8
# Clue: assortment, Weight: 1.8
# Clue: facility, Weight: 1.8
# Clue: limit, Weight: 1.8
# Clue: carpathians, Weight: 1.6400000000000001
# Clue: benelux, Weight: 1.6400000000000001
# Clue: baltic, Weight: 1.6400000000000001
# Clue: pyrenees, Weight: 1.6400000000000001
# Clue: iberia, Weight: 1.6400000000000001
# Clue: stratovolcano, Weight: 1.6400000000000001
# Clue: volcano, Weight: 1.6400000000000001
# Clue: rheinwaldhorn, Weight: 1.6400000000000001
# Clue: fujiyama, Weight: 1.6400000000000001
# Clue: ben, Weight: 1.6400000000000001
# Clue: outside, Weight: 1.6400000000000001
# Clue: find, Weight: 1.6400000000000001
# Clue: seamount, Weight: 1.6400000000000001
# Clue: earshot, Weight: 1.6400000000000001
# Clue: band, Weight: 1.6400000000000001
# Clue: view, Weight: 1.6400000000000001
# Clue: competition, Weight: 1.6
# Clue: european, Weight: 1.6
# Clue: union, Weight: 1.6
# Clue: asia, Weight: 1.6
# Clue: uefa, Weight: 1.6
# Clue: eurabia, Weight: 1.6
# Clue: nation, Weight: 1.6
# Clue: euro, Weight: 1.6
# Clue: europa, Weight: 1.6
# Clue: political, Weight: 1.6
# Clue: island, Weight: 1.6
# Clue: Matterhorn, Weight: 1.52
# Clue: Alps, Weight: 1.52
# Clue: Mont, Weight: 1.52
# Clue: Tyrolean, Weight: 1.52
# Clue: Blanc, Weight: 1.52
# Clue: Dolomite, Weight: 1.52
# Clue: Weisshorn, Weight: 1.52
# Clue: switzerland, Weight: 1.5
# Clue: mont, Weight: 1.5
# Clue: albion, Weight: 1.5
# Clue: alpine, Weight: 1.5
# Clue: slovenia, Weight: 1.5
# Clue: blanc, Weight: 1.5
# Clue: france, Weight: 1.5
# Clue: second, Weight: 1.48
# Clue: currant, Weight: 1.48
# Clue: people, Weight: 1.48
# Clue: republic, Weight: 1.48
# Clue: euromania, Weight: 1.48
# Clue: moldavia, Weight: 1.48
# Clue: beaker, Weight: 1.48
# Clue: europhiliac, Weight: 1.48
# Clue: ireland, Weight: 1.48
# Clue: red, Weight: 1.48
# Clue: spanish, Weight: 1.48
# Clue: Roman, Weight: 1.48
# Clue: Republic, Weight: 1.48

# %%
l = ['drive', 'dwarf', 'foot', 'moon', 'star', 'ghost', 'beijing', 'fighter', 'roulette', 'alp', 'dead', 'agent']
nlp = spacy.load("en_core_web_trf")
doc = nlp("driving")
for token in doc:
    if token.lemma_ not in l:
        print(token.text, token.lemma_)
# Out:
# driving driving

# %%
response = openai_client.responses.create(
    model="gpt-4.1",
    input = f"""The following are possible word classes: [ADV (adverb), ADJ (adjective), INTJ (interjection), NOUN (noun), PROPN (proper noun), VERB (verb)].
    
    Determine which of these classes the word 'table' belongs to based on its possible usages in English (and English only).
    
    At the end of your response, list the corresponding abbreviations (e.g., NOUN, VERB), separated by commas, on a single line.
    """

).output_text.split("\n")[-1]

# %%
response
# Out:
# 'NOUN, VERB'

# %%
word = "VOLDEMORT"
response = openAI_client.responses.create(
    model="gpt-4.1-nano",
    input = f"""
The possible word classes are: [ADJ (adjective), NOUN (noun), VERB (verb)].

Given the word {word}, identify which of these classes it can belong to based solely on its usage in English and English only.

Be as quick as you can. Respond with only the applicable abbreviations (e.g., NOUN, VERB), separated by commas, and nothing else.
"""

).output_text.split("\n")[-1]

print(response)
# Out:
# NOUN

# %%
from nltk.corpus import wordnet as wn

def get_pos(word):
    pos_set = set()
    for synset in wn.synsets(word):
        print(f"Synset: {synset}")
        if synset.name().split('.')[0] != word:
            continue  # Only consider exact matches
        if synset.pos() == 'n':
            pos_set.add('noun')
        elif synset.pos() == 'v':
            pos_set.add('verb')
        elif synset.pos() == 's':
            pos_set.add('adj')

    if len(pos_set) == 0:
        
            
    return pos_set

# Example usage
word = "DESTINY"
pos_tags = get_pos(word)
print(f"{word} can be used as: {', '.join(pos_tags)}")
# Out:
# Synset: Synset('destiny.n.01')
# Synset: Synset('destiny.n.02')
# Synset: Synset('fortune.n.04')
# DESTINY can be used as:

# %%
remove_stopwords("a city in France")
# Out:
# 'city France'

# %%
# Out:
# 9
# Time taken: 8.19223427772522
